# %%
import os
import pickle
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

from PIL import Image
import math
from sklearn.metrics import accuracy_score,hamming_loss, accuracy_score, f1_score, precision_score, recall_score

# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.metrics import multilabel_confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report

from textwrap import wrap


from utils import KunischMetrics
from utils import KunischPruner
from utils import DataExplorer
from utils import KunischPlotter

# %%
target = 'mr1'
target_name = 'Hamming Loss'
nlabels = [5, 14, 26, 34, 54, 63, 72, 82, 91, 107, 131, 169, 281]

# %%
output_dir = os.path.join('..', 'outputs')
output_em = os.path.join(output_dir, 'alexnet_75th', 'blur_rain_ref_rot_elastic1')
output_et = os.path.join(output_dir, 'resnet_E3', 'resnet18_evo', 'blur_rain_ref_rot_crop1_randaug1_elastic1', '5-281L')

# %%
# Iterar sobre archivos de resultados sacando el target buscado
scores_em = []
for n in nlabels:
    path_predicciones = os.path.join(output_em, f'{n}L_weighted_1', 'metadata.csv')
    predicciones = pd.read_csv(path_predicciones, index_col = 0)
    score = float(predicciones.loc[[target]].values[0][0])
    #print(path_predicciones, score[0][0])
    scores_em.append(score)
scores_em
# Out:
# [0.8814,
#  0.9214,
#  0.9201,
#  0.9458,
#  0.9407,
#  0.951,
#  0.9459,
#  0.9575,
#  0.9575,
#  0.9523,
#  0.951,
#  0.9575,
#  0.9626]

# %%
traductor_tradicional = {
    'acc': 'accuracy',
    'precision': 'precision',
    'hs' : 'hamming_score',
    'hl' : 'hamming_loss',
    'f1' : 'f1_score',
    'f2' : 'f2_score',
    'recall' : 'recall',
    'emr' : 'emr',
    'mr1' : '1mr',
    'mr2' : '2mr',
    'mr3' : '3mr',
    'mr4' : '4mr',
    'mr5' : '5mr'
}
# Iterar sobre archivos de resultados sacando el target buscado
path_predicciones = os.path.join(output_et, 'resultados.csv')
predicciones = pd.read_csv(path_predicciones, index_col = 0)
scores_et = predicciones[traductor_tradicional[target]].loc[['BR_LR']].values.tolist()
scores_et
# Out:
# [0.8878,
#  0.9356,
#  0.9446,
#  0.9459,
#  0.9575,
#  0.9549,
#  0.9588,
#  0.9575,
#  0.9613,
#  0.9562,
#  0.9536,
#  0.9485,
#  0.9485]

# %%
plt.rcParams.update({'font.size': 6})
plt.rcParams['figure.dpi'] = 1000
plotter = KunischPlotter()

# %%
valores = scores_em
auc = 0
for i in range(len(valores)-1):
    score_init = valores[i]
    score_final = valores[i+1]
    low_score = min(score_init, score_final)
    high_score = max(score_init, score_final)
    rectangulo = low_score * (nlabels[i+1] - nlabels[i]) 
    triangulo = high_score * (nlabels[i+1] - nlabels[i])/2
    auc += rectangulo + triangulo
auc
# Out:
# 393.40015

# %%
scores = [scores_et, scores_em]

labels = ['Enfoque Tradicional', 'Enfoque XMLC']
plotter.plot_results(nlabels,
             score = scores,
             label = labels,
             #title = target_name + ' v/s Cantidad de Etiquetas',
             xlabel = "Etiquetas a asignar", ylabel = target_name,
             ylim = 1.0,
             xlim = 300,
            width = 3.5,
             height = 6,
             grid = True,
             minorgrid = True,
            colors = ['tab:blue', 'tab:orange'])
# Out:
# D:\Escritorio\Semestre-envs\TesisMV\notebooks\utils.py:264: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
output_dir = os.path.join('..', 'outputs', 'cnn-rnn')

scores = {}

nlabels = [5, 14, 26, 34, 54, 63, 72, 82, 91, 107, 131, 169, 281]
experimento = 'base'
apellido = '_weighted_1'
targets = ['f2', 'recall', 'precision', 'hs']

# Armar diccionario de experimentos
for target in targets:
    scores[target] = []

# Iterar sobre archivos de resultados sacando el target buscado
for n in nlabels:
    for target in targets:
        path_metadata = os.path.join(output_dir, experimento, f'{n}L{apellido}', 'metadata.csv')
        metadata = pd.read_csv(path_metadata, index_col = 0)
        score_n = float(metadata.loc[[target]].values[0][0])
        #print(path_predicciones, score[0][0])
        scores[target].append(score_n)

# %%
scores
# Out:
# {'f2': [0.5022,
#   0.3482,
#   0.2488,
#   0.241,
#   0.1878,
#   0.1859,
#   0.1719,
#   0.1416,
#   0.1415,
#   0.1481,
#   0.1342,
#   0.0652,
#   0.0843],
#  'recall': [0.4905,
#   0.332,
#   0.2367,
#   0.2331,
#   0.1793,
#   0.1752,
#   0.1588,
#   0.1325,
#   0.135,
#   0.1439,
#   0.1316,
#   0.063,
#   0.0811],
#  'precision': [0.5903,
#   0.4633,
#   0.3404,
#   0.279,
#   0.2337,
#   0.246,
#   0.258,
#   0.1954,
#   0.1832,
#   0.1688,
#   0.1482,
#   0.0803,
#   0.1015],
#  'hs': [0.4657,
#   0.2865,
#   0.1917,
#   0.1767,
#   0.1308,
#   0.1244,
#   0.1216,
#   0.099,
#   0.0995,
#   0.1005,
#   0.0884,
#   0.0446,
#   0.057]}

# %%
plt.rcParams.update({'font.size': 6})
plt.rcParams['figure.dpi'] = 1000
plotter = KunischPlotter()

# %%
labels = ['Micro F2-Score', 'Micro Recall', 'Micro Precision', 'Hamming Score']
plotter.plot_results(nlabels,
             score = list(scores.values()),
             label = labels,
             #title = target_name + ' v/s Cantidad de Etiquetas',
             xlabel = "Etiquetas a asignar", ylabel = "Score",
             ylim = 1.0,
             xlim = 300,
             width = 3.5,
             height = 6,
             grid = True,
             minorgrid = True,
             )
# Out:
# D:\Escritorio\Semestre-envs\TesisMV\notebooks\utils.py:260: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
output_dir = os.path.join('..', 'outputs', 'cnn-rnn')

scores = {}

nlabels = [5, 14, 26, 34, 54, 63, 72, 82, 91, 107, 131, 169, 281]
experimentos = ['base', 'crop1', 'blur_rain_ref_rot_crop1_randaug1_elastic1']
apellido = '_weighted_1'
targets = ['f2', 'recall', 'precision', 'hs', 'emr', 'mr5']

# Armar diccionario de experimentos
for n in nlabels:
    for exp in experimentos:
        scores[exp + ';' + str(n)] = {}

# Iterar sobre archivos de resultados sacando el target buscado
for n in nlabels:
    for experimento in experimentos:
        for target in targets:
            path_metadata = os.path.join(output_dir, experimento, f'{n}L{apellido}', 'metadata.csv')
            metadata = pd.read_csv(path_metadata, index_col = 0)
            score = float(metadata.loc[[target]].values[0][0])
            scores[experimento + ';' + str(n)][target] = score

da_map = {
    'base': 0,
    'rot': 1,
    'ref': 2,
    'crop1': 3,
    'elastic1': 4,
    'rain': 5,
    'randaug1': 6,
    'gausblur1': 7,
    'blur': 8,
    'mtnblur': 9,
    'ref_rot': 10,
    'rain_ref_rot': 11,
    'rain_ref_rot_elastic1': 12,
    'blur_rain_ref_rot_elastic1': 13,
    'blur_rain_ref_rot_crop1_elastic1': 14,
    'blur_rain_ref_rot_crop1_randaug1_elastic1': 15,
}

# %%
scores
# Out:
# {'base;5': {'f2': 0.5022,
#   'recall': 0.4905,
#   'precision': 0.5903,
#   'hs': 0.4657,
#   'emr': 0.3544,
#   'mr5': 0.4601},
#  'crop1;5': {'f2': 0.5371,
#   'recall': 0.5145,
#   'precision': 0.6656,
#   'hs': 0.4894,
#   'emr': 0.3879,
#   'mr5': 0.4871},
#  'blur_rain_ref_rot_crop1_randaug1_elastic1;5': {'f2': 0.0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'hs': 0.201,
#   'emr': 0.201,
#   'mr5': 0.201},
#  'base;14': {'f2': 0.3482,
#   'recall': 0.332,
#   'precision': 0.4633,
#   'hs': 0.2865,
#   'emr': 0.107,
#   'mr5': 0.2049},
#  'crop1;14': {'f2': 0.3748,
#   'recall': 0.3503,
#   'precision': 0.5305,
#   'hs': 0.3263,
#   'emr': 0.1405,
#   'mr5': 0.1894},
#  'blur_rain_ref_rot_crop1_randaug1_elastic1;14': {'f2': 0.0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'hs': 0.058,
#   'emr': 0.058,
#   'mr5': 0.058},
#  'base;26': {'f2': 0.2488,
#   'recall': 0.2367,
#   'precision': 0.3404,
#   'hs': 0.1917,
#   'emr': 0.0245,
#   'mr5': 0.0851},
#  'crop1;26': {'f2': 0.2498,
#   'recall': 0.2386,
#   'precision': 0.3101,
#   'hs': 0.1877,
#   'emr': 0.0426,
#   'mr5': 0.0928},
#  'blur_rain_ref_rot_crop1_randaug1_elastic1;26': {'f2': 0.0113,
#   'recall': 0.0092,
#   'precision': 0.1875,
#   'hs': 0.0309,
#   'emr': 0.0232,
#   'mr5': 0.0232},
#  'base;34': {'f2': 0.241,
#   'recall': 0.2331,
#   'precision': 0.279,
#   'hs': 0.1767,
#   'emr': 0.0155,
#   'mr5': 0.0619},
#  'crop1;34': {'f2': 0.1912,
#   'recall': 0.1763,
#   'precision': 0.291,
#   'hs': 0.1458,
#   'emr': 0.0193,
#   'mr5': 0.0554},
#  'blur_rain_ref_rot_crop1_randaug1_elastic1;34': {'f2': 0.0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'hs': 0.018,
#   'emr': 0.018,
#   'mr5': 0.018},
#  'base;54': {'f2': 0.1878,
#   'recall': 0.1793,
#   'precision': 0.2337,
#   'hs': 0.1308,
#   'emr': 0.0155,
#   'mr5': 0.0477},
#  'crop1;54': {'f2': 0.1656,
#   'recall': 0.1571,
#   'precision': 0.2183,
#   'hs': 0.1209,
#   'emr': 0.0142,
#   'mr5': 0.0438},
#  'blur_rain_ref_rot_crop1_randaug1_elastic1;54': {'f2': 0.0318,
#   'recall': 0.0259,
#   'precision': 0.4248,
#   'hs': 0.0426,
#   'emr': 0.0193,
#   'mr5': 0.0193},
#  'base;63': {'f2': 0.1859,
#   'recall': 0.1752,
#   'precision': 0.246,
#   'hs': 0.1244,
#   'emr': 0.0142,
#   'mr5': 0.0425},
#  'crop1;63': {'f2': 0.173,
#   'recall': 0.1592,
#   'precision': 0.2678,
#   'hs': 0.1264,
#   'emr': 0.0116,
#   'mr5': 0.0296},
#  'blur_rain_ref_rot_crop1_randaug1_elastic1;63': {'f2': 0.0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'hs': 0.0103,
#   'emr': 0.0103,
#   'mr5': 0.0103},
#  'base;72': {'f2': 0.1719,
#   'recall': 0.1588,
#   'precision': 0.258,
#   'hs': 0.1216,
#   'emr': 0.0142,
#   'mr5': 0.0335},
#  'crop1;72': {'f2': 0.1544,
#   'recall': 0.1434,
#   'precision': 0.2251,
#   'hs': 0.1137,
#   'emr': 0.0129,
#   'mr5': 0.0284},
#  'blur_rain_ref_rot_crop1_randaug1_elastic1;72': {'f2': 0.0038,
#   'recall': 0.0032,
#   'precision': 0.012,
#   'hs': 0.0102,
#   'emr': 0.0078,
#   'mr5': 0.0103},
#  'base;82': {'f2': 0.1416,
#   'recall': 0.1325,
#   'precision': 0.1954,
#   'hs': 0.099,
#   'emr': 0.0065,
#   'mr5': 0.0219},
#  'crop1;82': {'f2': 0.171,
#   'recall': 0.1595,
#   'precision': 0.2414,
#   'hs': 0.1193,
#   'emr': 0.009,
#   'mr5': 0.0232},
#  'blur_rain_ref_rot_crop1_randaug1_elastic1;82': {'f2': 0.0084,
#   'recall': 0.0068,
#   'precision': 0.3935,
#   'hs': 0.0153,
#   'emr': 0.009,
#   'mr5': 0.009},
#  'base;91': {'f2': 0.1415,
#   'recall': 0.135,
#   'precision': 0.1832,
#   'hs': 0.0995,
#   'emr': 0.009,
#   'mr5': 0.0219},
#  'crop1;91': {'f2': 0.1901,
#   'recall': 0.1812,
#   'precision': 0.2423,
#   'hs': 0.1329,
#   'emr': 0.009,
#   'mr5': 0.0245},
#  'blur_rain_ref_rot_crop1_randaug1_elastic1;91': {'f2': 0.0196,
#   'recall': 0.0162,
#   'precision': 0.1394,
#   'hs': 0.0231,
#   'emr': 0.0077,
#   'mr5': 0.0077},
#  'base;107': {'f2': 0.1481,
#   'recall': 0.1439,
#   'precision': 0.1688,
#   'hs': 0.1005,
#   'emr': 0.0013,
#   'mr5': 0.0065},
#  'crop1;107': {'f2': 0.1839,
#   'recall': 0.1697,
#   'precision': 0.2809,
#   'hs': 0.1404,
#   'emr': 0.0116,
#   'mr5': 0.0193},
#  'blur_rain_ref_rot_crop1_randaug1_elastic1;107': {'f2': 0.0254,
#   'recall': 0.0212,
#   'precision': 0.1904,
#   'hs': 0.0241,
#   'emr': 0.0064,
#   'mr5': 0.0077},
#  'base;131': {'f2': 0.1342,
#   'recall': 0.1316,
#   'precision': 0.1482,
#   'hs': 0.0884,
#   'emr': 0.0039,
#   'mr5': 0.009},
#  'crop1;131': {'f2': 0.0631,
#   'recall': 0.0593,
#   'precision': 0.0856,
#   'hs': 0.0391,
#   'emr': 0.0026,
#   'mr5': 0.0065},
#  'blur_rain_ref_rot_crop1_randaug1_elastic1;131': {'f2': 0.0335,
#   'recall': 0.0288,
#   'precision': 0.0958,
#   'hs': 0.029,
#   'emr': 0.0052,
#   'mr5': 0.0052},
#  'base;169': {'f2': 0.0652,
#   'recall': 0.063,
#   'precision': 0.0803,
#   'hs': 0.0446,
#   'emr': 0.0052,
#   'mr5': 0.0052},
#  'crop1;169': {'f2': 0.0334,
#   'recall': 0.0322,
#   'precision': 0.0421,
#   'hs': 0.0238,
#   'emr': 0.0052,
#   'mr5': 0.0065},
#  'blur_rain_ref_rot_crop1_randaug1_elastic1;169': {'f2': 0.041,
#   'recall': 0.0363,
#   'precision': 0.0896,
#   'hs': 0.0332,
#   'emr': 0.009,
#   'mr5': 0.009},
#  'base;281': {'f2': 0.0843,
#   'recall': 0.0811,
#   'precision': 0.1015,
#   'hs': 0.057,
#   'emr': 0.0039,
#   'mr5': 0.0039},
#  'crop1;281': {'f2': 0.0429,
#   'recall': 0.0398,
#   'precision': 0.062,
#   'hs': 0.0278,
#   'emr': 0.0026,
#   'mr5': 0.0026},
#  'blur_rain_ref_rot_crop1_randaug1_elastic1;281': {'f2': 0.0727,
#   'recall': 0.0645,
#   'precision': 0.1533,
#   'hs': 0.0507,
#   'emr': 0.0052,
#   'mr5': 0.0052}}

# %%
df = pd.DataFrame.from_dict(scores, orient='index')

# %%
df['etiquetas'] =[x.split(';')[1] for x in list(df.index.values)]
df['conjunto'] = [da_map[x.split(';')[0]] for x in list(df.index.values)]
df = df[['conjunto', 'etiquetas','f2', 'recall', 'precision', 'hs', 'emr', 'mr5']]
df
# Out:
#                                                conjunto etiquetas      f2  \
# base;5                                                0         5  0.5022
# crop1;5                                               3         5  0.5371
# blur_rain_ref_rot_crop1_randaug1_elastic1;5          15         5  0.0000
# base;14                                               0        14  0.3482
# crop1;14                                              3        14  0.3748
# blur_rain_ref_rot_crop1_randaug1_elastic1;14         15        14  0.0000
# base;26                                               0        26  0.2488
# crop1;26                                              3        26  0.2498
# blur_rain_ref_rot_crop1_randaug1_elastic1;26         15        26  0.0113
# base;34                                               0        34  0.2410
# crop1;34                                              3        34  0.1912
# blur_rain_ref_rot_crop1_randaug1_elastic1;34         15        34  0.0000
# base;54                                               0        54  0.1878
# crop1;54                                              3        54  0.1656
# blur_rain_ref_rot_crop1_randaug1_elastic1;54         15        54  0.0318
# base;63                                               0        63  0.1859
# crop1;63                                              3        63  0.1730
# blur_rain_ref_rot_crop1_randaug1_elastic1;63         15        63  0.0000
# base;72                                               0        72  0.1719
# crop1;72                                              3        72  0.1544
# blur_rain_ref_rot_crop1_randaug1_elastic1;72         15        72  0.0038
# base;82                                               0        82  0.1416
# crop1;82                                              3        82  0.1710
# blur_rain_ref_rot_crop1_randaug1_elastic1;82         15        82  0.0084
# base;91                                               0        91  0.1415
# crop1;91                                              3        91  0.1901
# blur_rain_ref_rot_crop1_randaug1_elastic1;91         15        91  0.0196
# base;107                                              0       107  0.1481
# crop1;107                                             3       107  0.1839
# blur_rain_ref_rot_crop1_randaug1_elastic1;107        15       107  0.0254
# base;131                                              0       131  0.1342
# crop1;131                                             3       131  0.0631
# blur_rain_ref_rot_crop1_randaug1_elastic1;131        15       131  0.0335
# base;169                                              0       169  0.0652
# crop1;169                                             3       169  0.0334
# blur_rain_ref_rot_crop1_randaug1_elastic1;169        15       169  0.0410
# base;281                                              0       281  0.0843
# crop1;281                                             3       281  0.0429
# blur_rain_ref_rot_crop1_randaug1_elastic1;281        15       281  0.0727
#
#                                                recall  precision      hs  \
# base;5                                         0.4905     0.5903  0.4657
# crop1;5                                        0.5145     0.6656  0.4894
# blur_rain_ref_rot_crop1_randaug1_elastic1;5    0.0000     0.0000  0.2010
# base;14                                        0.3320     0.4633  0.2865
# crop1;14                                       0.3503     0.5305  0.3263
# blur_rain_ref_rot_crop1_randaug1_elastic1;14   0.0000     0.0000  0.0580
# base;26                                        0.2367     0.3404  0.1917
# crop1;26                                       0.2386     0.3101  0.1877
# blur_rain_ref_rot_crop1_randaug1_elastic1;26   0.0092     0.1875  0.0309
# base;34                                        0.2331     0.2790  0.1767
# crop1;34                                       0.1763     0.2910  0.1458
# blur_rain_ref_rot_crop1_randaug1_elastic1;34   0.0000     0.0000  0.0180
# base;54                                        0.1793     0.2337  0.1308
# crop1;54                                       0.1571     0.2183  0.1209
# blur_rain_ref_rot_crop1_randaug1_elastic1;54   0.0259     0.4248  0.0426
# base;63                                        0.1752     0.2460  0.1244
# crop1;63                                       0.1592     0.2678  0.1264
# blur_rain_ref_rot_crop1_randaug1_elastic1;63   0.0000     0.0000  0.0103
# base;72                                        0.1588     0.2580  0.1216
# crop1;72                                       0.1434     0.2251  0.1137
# blur_rain_ref_rot_crop1_randaug1_elastic1;72   0.0032     0.0120  0.0102
# base;82                                        0.1325     0.1954  0.0990
# crop1;82                                       0.1595     0.2414  0.1193
# blur_rain_ref_rot_crop1_randaug1_elastic1;82   0.0068     0.3935  0.0153
# base;91                                        0.1350     0.1832  0.0995
# crop1;91                                       0.1812     0.2423  0.1329
# blur_rain_ref_rot_crop1_randaug1_elastic1;91   0.0162     0.1394  0.0231
# base;107                                       0.1439     0.1688  0.1005
# crop1;107                                      0.1697     0.2809  0.1404
# blur_rain_ref_rot_crop1_randaug1_elastic1;107  0.0212     0.1904  0.0241
# base;131                                       0.1316     0.1482  0.0884
# crop1;131                                      0.0593     0.0856  0.0391
# blur_rain_ref_rot_crop1_randaug1_elastic1;131  0.0288     0.0958  0.0290
# base;169                                       0.0630     0.0803  0.0446
# crop1;169                                      0.0322     0.0421  0.0238
# blur_rain_ref_rot_crop1_randaug1_elastic1;169  0.0363     0.0896  0.0332
# base;281                                       0.0811     0.1015  0.0570
# crop1;281                                      0.0398     0.0620  0.0278
# blur_rain_ref_rot_crop1_randaug1_elastic1;281  0.0645     0.1533  0.0507
#
#                                                   emr     mr5
# base;5                                         0.3544  0.4601
# crop1;5                                        0.3879  0.4871
# blur_rain_ref_rot_crop1_randaug1_elastic1;5    0.2010  0.2010
# base;14                                        0.1070  0.2049
# crop1;14                                       0.1405  0.1894
# blur_rain_ref_rot_crop1_randaug1_elastic1;14   0.0580  0.0580
# base;26                                        0.0245  0.0851
# crop1;26                                       0.0426  0.0928
# blur_rain_ref_rot_crop1_randaug1_elastic1;26   0.0232  0.0232
# base;34                                        0.0155  0.0619
# crop1;34                                       0.0193  0.0554
# blur_rain_ref_rot_crop1_randaug1_elastic1;34   0.0180  0.0180
# base;54                                        0.0155  0.0477
# crop1;54                                       0.0142  0.0438
# blur_rain_ref_rot_crop1_randaug1_elastic1;54   0.0193  0.0193
# base;63                                        0.0142  0.0425
# crop1;63                                       0.0116  0.0296
# blur_rain_ref_rot_crop1_randaug1_elastic1;63   0.0103  0.0103
# base;72                                        0.0142  0.0335
# crop1;72                                       0.0129  0.0284
# blur_rain_ref_rot_crop1_randaug1_elastic1;72   0.0078  0.0103
# base;82                                        0.0065  0.0219
# crop1;82                                       0.0090  0.0232
# blur_rain_ref_rot_crop1_randaug1_elastic1;82   0.0090  0.0090
# base;91                                        0.0090  0.0219
# crop1;91                                       0.0090  0.0245
# blur_rain_ref_rot_crop1_randaug1_elastic1;91   0.0077  0.0077
# base;107                                       0.0013  0.0065
# crop1;107                                      0.0116  0.0193
# blur_rain_ref_rot_crop1_randaug1_elastic1;107  0.0064  0.0077
# base;131                                       0.0039  0.0090
# crop1;131                                      0.0026  0.0065
# blur_rain_ref_rot_crop1_randaug1_elastic1;131  0.0052  0.0052
# base;169                                       0.0052  0.0052
# crop1;169                                      0.0052  0.0065
# blur_rain_ref_rot_crop1_randaug1_elastic1;169  0.0090  0.0090
# base;281                                       0.0039  0.0039
# crop1;281                                      0.0026  0.0026
# blur_rain_ref_rot_crop1_randaug1_elastic1;281  0.0052  0.0052

# %%
df.to_csv("Experimento9.csv")
